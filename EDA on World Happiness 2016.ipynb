# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)
from scipy import stats
import warnings
warnings.filterwarnings("ignore")
import os

# %%
data=pd.read_csv(r"world_happiness_2016.csv")
h_df=pd.DataFrame(data)
h_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
h_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
h_df.index
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
h_df.shape
# Out:
# (157, 13)

# %%
h_df.count()
# Out:
# Country                          157
# Region                           157
# Happiness Rank                   157
# Happiness Score                  157
# Lower Confidence Interval        157
# Upper Confidence Interval        157
# Economy (GDP per Capita)         157
# Family                           157
# Health (Life Expectancy)         157
# Freedom                          157
# Trust (Government Corruption)    157
# Generosity                       157
# Dystopia Residual                157
# dtype: int64

# %%
h_df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
column=h_df.columns
for i in column:
    print("=>",i)
# Out:
# => Country
# => Region
# => Happiness Rank
# => Happiness Score
# => Lower Confidence Interval
# => Upper Confidence Interval
# => Economy (GDP per Capita)
# => Family
# => Health (Life Expectancy)
# => Freedom
# => Trust (Government Corruption)
# => Generosity
# => Dystopia Residual

# %%
h_df.nunique()
# Out:
# Country                          157
# Region                            10
# Happiness Rank                   154
# Happiness Score                  154
# Lower Confidence Interval        154
# Upper Confidence Interval        154
# Economy (GDP per Capita)         157
# Family                           157
# Health (Life Expectancy)         156
# Freedom                          157
# Trust (Government Corruption)    156
# Generosity                       157
# Dystopia Residual                157
# dtype: int64

# %%
h_df.rename(columns = {"Economy (GDP per Capita)": "Economy", "Health (Life Expectancy)":"Health", "Trust (Government Corruption)":"Trust"},inplace = True)
h_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
data=h_df[["Country","Happiness Score"]].sort_values(by="Happiness Score",ascending=False).head(10)
data
# Out:
#        Country  Happiness Score
# 0      Denmark            7.526
# 1  Switzerland            7.509
# 2      Iceland            7.501
# 3       Norway            7.498
# 4      Finland            7.413
# 5       Canada            7.404
# 6  Netherlands            7.339
# 7  New Zealand            7.334
# 8    Australia            7.313
# 9       Sweden            7.291

# %%
h_df.drop(["Lower Confidence Interval","Upper Confidence Interval"],axis=1,inplace=True)

# %%
h_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy   Family   Health  Freedom    Trust  Generosity  \
# 0              7.526  1.44178  1.16374  0.79504  0.57941  0.44453     0.36171
# ...

# %%
outliers=h_df.loc[:,"Happiness Score":]
plt.figure(figsize=(12,6))
sns.boxplot(outliers)
# Out:
# <Axes: >

# %%
print(round(h_df.loc[:,"Happiness Score":].mean(),2)) #Finding Mean of the data set
# Out:
# Happiness Score      5.38
# Economy              0.95
# Family               0.79
# Health               0.56
# Freedom              0.37
# Trust                0.14
# Generosity           0.24
# Dystopia Residual    2.33
# dtype: float64

# %%
print(round(h_df.loc[:,"Happiness Score":].median(),2)) #Finding Median of the data set
# Out:
# Happiness Score      5.31
# Economy              1.03
# Family               0.84
# Health               0.60
# Freedom              0.40
# Trust                0.11
# Generosity           0.22
# Dystopia Residual    2.29
# dtype: float64

# %%
print(round(h_df.loc[:,"Happiness Score":].std(),2)) #Finding Standard Deviation of the data set
# Out:
# Happiness Score      1.14
# Economy              0.41
# Family               0.27
# Health               0.23
# Freedom              0.15
# Trust                0.11
# Generosity           0.13
# Dystopia Residual    0.54
# dtype: float64

# %%
#select Country,Region and Happiness score and sorting the values by Happiness score
h_df[["Country","Region","Happiness Score"]].sort_values(by="Happiness Score",ascending=False).head(10)
# Out:
#        Country                     Region  Happiness Score
# 0      Denmark             Western Europe            7.526
# 1  Switzerland             Western Europe            7.509
# 2      Iceland             Western Europe            7.501
# 3       Norway             Western Europe            7.498
# 4      Finland             Western Europe            7.413
# 5       Canada              North America            7.404
# 6  Netherlands             Western Europe            7.339
# 7  New Zealand  Australia and New Zealand            7.334
# 8    Australia  Australia and New Zealand            7.313
# 9       Sweden             Western Europe            7.291

# %% [markdown]
#  Western European countries takes the upper postion in Happiness Score

# %%
h_df[["Country","Region","Happiness Score"]].sort_values(by="Happiness Score",ascending=False).tail(10)
# Out:
#          Country                           Region  Happiness Score
# 147   Madagascar               Sub-Saharan Africa            3.695
# 148     Tanzania               Sub-Saharan Africa            3.666
# 149      Liberia               Sub-Saharan Africa            3.622
# 150       Guinea               Sub-Saharan Africa            3.607
# 151       Rwanda               Sub-Saharan Africa            3.515
# 152        Benin               Sub-Saharan Africa            3.484
# 153  Afghanistan                    Southern Asia            3.360
# 154         Togo               Sub-Saharan Africa            3.303
# 155        Syria  Middle East and Northern Africa            3.069
# 156      Burundi               Sub-Saharan Africa            2.905

# %% [markdown]
# African countries takes the lower postion in Happiness Score

# %%
round(h_df[["Region", "Happiness Score"]].groupby(by = "Region").describe(),4)
# Out:
#                                 Happiness Score                         \
#                                           count    mean     std    min
# Region
# Australia and New Zealand                   2.0  7.3235  0.0148  7.313
# Central and Eastern Europe                 29.0  5.3707  0.5904  4.217
# Eastern Asia                                6.0  5.6242  0.5269  4.907
# Latin America and Caribbean                24.0  6.1018  0.7257  4.028
# Middle East and Northern Africa            19.0  5.3861  1.0576  3.069
# North America                               2.0  7.2540  0.2121  7.104
# Southeastern Asia                           9.0  5.3389  0.9307  3.907
# Southern Asia                               7.0  4.5633  0.6162  3.360
# Sub-Saharan Africa                         38.0  4.1364  0.5585  2.905
# Western Europe                             21.0  6.6857  0.7892  5.033
#
#
#                                     25%     50%     75%    max
# Region
# ...

# %%
visu=h_df[["Country","Region","Happiness Score"]].groupby(by="Region").mean().sort_values(by="Happiness Score",ascending=False)

# %%
visu
# Out:
#                                  Happiness Score
# Region
# Australia and New Zealand               7.323500
# North America                           7.254000
# Western Europe                          6.685667
# Latin America and Caribbean             6.101750
# Eastern Asia                            5.624167
# Middle East and Northern Africa         5.386053
# Central and Eastern Europe              5.370690
# Southeastern Asia                       5.338889
# Southern Asia                           4.563286
# Sub-Saharan Africa                      4.136421

# %%
plt.figure(figsize=(9,5))
sns.barplot(x=visu['Happiness Score'],y=visu.index)
plt.show()
